# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\lucas.vianna\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\lucas.vianna\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # First Step

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generating Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# # Performing API Calls + Converting Raw Data to DataFrame

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=00e4d6935804b95e3b57275e6ee88726&units=imperial&q='

# %%
# set up lists to hold reponse info

city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

record = 1

print("Beginning Data Retrieval ")
print("Loading---------------------------------------")

for city in cities:  
 
    try: 
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"]) 
        city_record = response["name"]
        
        
        print(f"Processing Record {record} | {city_record}")
  
        # Increase counter by one 
        record= record + 1
        
  
    except:
        print("City not found...")
    continue
# Out:
# Beginning Data Retrieval
# Loading---------------------------------------
# Processing Record 1 | Puerto Ayora
# Processing Record 2 | Jamestown
# Processing Record 3 | Busselton
# City not found...
# Processing Record 4 | Yellowknife
# Processing Record 5 | Ushuaia
# Processing Record 6 | Hualmay
# Processing Record 7 | Siddharthanagar
# Processing Record 8 | Muros
# Processing Record 9 | Srīvardhan
# Processing Record 10 | Hokitika
# Processing Record 11 | Vangaindrano
# Processing Record 12 | Kenai
# Processing Record 13 | Saint Paul Harbor
# Processing Record 14 | Djambala
# Processing Record 15 | Mataura
# Processing Record 16 | Atuona
# Processing Record 17 | Souillac
# Processing Record 18 | Avarua
# Processing Record 19 | Norman Wells
# Processing Record 20 | Cuerámaro
# City not found...
# Processing Record 21 | Kahului
# Processing Record 22 | Boca de Parita
# Processing Record 23 | Qaanaaq
# Processing Record 24 | Krechevitsy
# Processing Record 25 | Dunedin
# Processing Record 26 | Port Elizabeth
# Processing Record 27 | Mahē
# Processing Record 28 | Clyde River
# Processing Record 29 | Dikson
# Processing Record 30 | Biak
# Processing Record 31 | Kjøllefjord
# Processing Record 32 | Santa Rosa
# Processing Record 33 | Kapaa
# Processing Record 34 | Rikitea
# City not found...
# Processing Record 35 | Punta Arenas
# Processing Record 36 | Port Alfred
# Processing Record 37 | Vostok
# Processing Record 38 | Hithadhoo
# Processing Record 39 | Hilo
# Processing Record 40 | Huesca
# Processing Record 41 | Verāval
# City not found...
# Processing Record 42 | Rincon
# Processing Record 43 | Saskylakh
# Processing Record 44 | Saint George
# City not found...
# Processing Record 45 | Lagoa
# Processing Record 46 | Ancud
# Processing Record 47 | São Filipe
# City not found...
# Processing Record 48 | Portland
# Processing Record 49 | Port Maria
# Processing Record 50 | Carnarvon
# Processing Record 51 | Provideniya
# Processing Record 52 | Barrow
# Processing Record 53 | Chokurdakh
# Processing Record 54 | Salalah
# Processing Record 55 | Alice Springs
# Processing Record 56 | Marzuq
# Processing Record 57 | Honiara
# Processing Record 58 | Nikolskoye
# Processing Record 59 | Kismayo
# Processing Record 60 | Ongandjera
# Processing Record 61 | Bathsheba
# City not found...
# Processing Record 62 | San-Pédro
# Processing Record 63 | Hermanus
# Processing Record 64 | Moose Factory
# Processing Record 65 | Lüderitz
# Processing Record 66 | Comodoro Rivadavia
# Processing Record 67 | Olafsvik
# Processing Record 68 | Lompoc
# Processing Record 69 | Vaini
# Processing Record 70 | Bar Harbor
# Processing Record 71 | Thompson
# Processing Record 72 | Shache
# Processing Record 73 | Pimentel
# Processing Record 74 | Cape Town
# Processing Record 75 | Moa
# Processing Record 76 | Hasaki
# Processing Record 77 | Bluff
# Processing Record 78 | Nago
# Processing Record 79 | Manubul
# Processing Record 80 | Huarmey
# Processing Record 81 | Albany
# Processing Record 82 | Klyuchi
# Processing Record 83 | Ryabovo
# City not found...
# Processing Record 84 | Mar del Plata
# Processing Record 85 | Lorengau
# Processing Record 86 | Aklavik
# Processing Record 87 | Vardø
# Processing Record 88 | Somerset East
# Processing Record 89 | Arraial do Cabo
# Processing Record 90 | Søgne
# Processing Record 91 | Saint-Philippe
# Processing Record 92 | Hobart
# Processing Record 93 | Yuncheng
# Processing Record 94 | Raymond
# Processing Record 95 | Diego de Almagro
# Processing Record 96 | Esperance
# Processing Record 97 | Cabo San Lucas
# Processing Record 98 | Ouésso
# Processing Record 99 | Klaksvík
# Processing Record 100 | Cheyenne
# Processing Record 101 | Butaritari
# Processing Record 102 | Katsuura
# Processing Record 103 | Dengzhou
# Processing Record 104 | Chapadinha
# Processing Record 105 | Narrabri
# Processing Record 106 | Dingle
# City not found...
# Processing Record 107 | Micomeseng
# Processing Record 108 | Guiratinga
# Processing Record 109 | Bredasdorp
# Processing Record 110 | Morón
# Processing Record 111 | Hoa Binh
# Processing Record 112 | Geraldton
# Processing Record 113 | Nanortalik
# Processing Record 114 | Pisco
# Processing Record 115 | George Town
# Processing Record 116 | Te Anau
# Processing Record 117 | Novorzhev
# Processing Record 118 | Mareeba
# Processing Record 119 | Nur-Sultan
# Processing Record 120 | Altay
# Processing Record 121 | Hofn
# Processing Record 122 | Henderson
# Processing Record 123 | Marsá Maţrūḩ
# Processing Record 124 | Kumul
# Processing Record 125 | Bāsār
# Processing Record 126 | Al Bardīyah
# Processing Record 127 | Palau
# Processing Record 128 | Hong Kong
# Processing Record 129 | Rocha
# Processing Record 130 | Saint-Augustin
# Processing Record 131 | Bengkulu
# Processing Record 132 | Ribeira Grande
# Processing Record 133 | Bambous Virieux
# Processing Record 134 | Tiarei
# City not found...
# Processing Record 135 | Iqaluit
# Processing Record 136 | Abilene
# Processing Record 137 | Ankang
# Processing Record 138 | Borzya
# Processing Record 139 | Coyhaique
# Processing Record 140 | Hadrut
# Processing Record 141 | Fuyang
# Processing Record 142 | Puerto Cabezas
# Processing Record 143 | Vipperød
# Processing Record 144 | Jacqueville
# Processing Record 145 | Bud
# Processing Record 146 | Pangnirtung
# Processing Record 147 | Khatanga
# Processing Record 148 | Faanui
# Processing Record 149 | San Patricio
# Processing Record 150 | Kiama
# Processing Record 151 | Tasiilaq
# Processing Record 152 | Sivaki
# Processing Record 153 | Puerto Madryn
# Processing Record 154 | Grindavik
# Processing Record 155 | Hollins
# Processing Record 156 | Puerto Madero
# Processing Record 157 | Tiksi
# Processing Record 158 | Isangel
# Processing Record 159 | Ilulissat
# Processing Record 160 | San Cristobal
# Processing Record 161 | Northam
# City not found...
# City not found...
# City not found...
# Processing Record 162 | Yerbogachën
# Processing Record 163 | Port-Cartier
# Processing Record 164 | Mashhad
# Processing Record 165 | Viedma
# Processing Record 166 | Cayenne
# Processing Record 167 | Half Moon Bay
# Processing Record 168 | Yangi Marg`ilon
# Processing Record 169 | Vestmanna
# City not found...
# Processing Record 170 | Valleyview
# Processing Record 171 | Batemans Bay
# City not found...
# Processing Record 172 | Chui
# Processing Record 173 | Saldanha
# Processing Record 174 | Vulcan
# Processing Record 175 | Lincoln
# Processing Record 176 | Pevek
# Processing Record 177 | Torbay
# Processing Record 178 | Buchanan
# City not found...
# Processing Record 179 | Mubi
# Processing Record 180 | San Quintín
# Processing Record 181 | Castro
# Processing Record 182 | Yagodnoye
# Processing Record 183 | Kommunar
# Processing Record 184 | Saint-Pierre
# Processing Record 185 | Tuktoyaktuk
# City not found...
# Processing Record 186 | Minna
# Processing Record 187 | Ol'ga
# Processing Record 188 | Hobyo
# City not found...
# Processing Record 189 | Longyearbyen
# Processing Record 190 | Marawi
# City not found...
# Processing Record 191 | Muscat
# Processing Record 192 | Kununurra
# Processing Record 193 | Avigliano
# Processing Record 194 | La Palma
# Processing Record 195 | Juazeiro
# Processing Record 196 | Gamba
# Processing Record 197 | Tuatapere
# Processing Record 198 | Kloulklubed
# Processing Record 199 | Lebu
# City not found...
# Processing Record 200 | Cururupu
# Processing Record 201 | Meulaboh
# Processing Record 202 | High Level
# Processing Record 203 | Micheweni
# Processing Record 204 | New Norfolk
# City not found...
# Processing Record 205 | Koungheul
# Processing Record 206 | Alofi
# Processing Record 207 | Bānswāda
# Processing Record 208 | Dukat
# Processing Record 209 | Yarmouth
# Processing Record 210 | Am Timan
# Processing Record 211 | Caravelas
# Processing Record 212 | Maţāy
# Processing Record 213 | Darhan
# Processing Record 214 | Cockburn Town
# Processing Record 215 | Ţaga
# Processing Record 216 | Lavrentiya
# Processing Record 217 | Tautira
# Processing Record 218 | Iquique
# City not found...
# Processing Record 219 | Kamina
# Processing Record 220 | Sitka
# Processing Record 221 | Sigayevo
# Processing Record 222 | Bor
# Processing Record 223 | Caxias
# Processing Record 224 | Behshahr
# Processing Record 225 | Bath
# Processing Record 226 | Bethel
# Processing Record 227 | San Rafael
# Processing Record 228 | Morondava
# Processing Record 229 | El Salvador
# Processing Record 230 | Saurimo
# City not found...
# Processing Record 231 | Emerald
# Processing Record 232 | Darnah
# Processing Record 233 | Danané
# Processing Record 234 | Iranshahr
# Processing Record 235 | Mahabalipuram
# Processing Record 236 | Stykkisholmur
# Processing Record 237 | Aberdare
# Processing Record 238 | Berlevåg
# Processing Record 239 | Najrān
# Processing Record 240 | Muchkapskiy
# Processing Record 241 | Ponta do Sol
# City not found...
# City not found...
# Processing Record 242 | Mossamedes
# Processing Record 243 | Russell
# Processing Record 244 | Fortuna
# Processing Record 245 | Faya
# Processing Record 246 | Araouane
# City not found...
# Processing Record 247 | Anadyr
# Processing Record 248 | Ingham
# Processing Record 249 | Kavaratti
# Processing Record 250 | Río Gallegos
# Processing Record 251 | Qingdao
# Processing Record 252 | Kruisfontein
# Processing Record 253 | Smolenka
# Processing Record 254 | Oddur
# Processing Record 255 | Vestmannaeyjar
# City not found...
# Processing Record 256 | Roald
# City not found...
# Processing Record 257 | Srednekolymsk
# Processing Record 258 | São Bento do Sul
# Processing Record 259 | Economy
# City not found...
# Processing Record 260 | Nizhnevartovsk
# Processing Record 261 | Antofagasta
# Processing Record 262 | Cankuzo Province
# Processing Record 263 | Yulara
# Processing Record 264 | Oranjemund
# Processing Record 265 | Airai
# Processing Record 266 | Bridlington
# Processing Record 267 | Vao
# Processing Record 268 | Husavik
# Processing Record 269 | Castanheira de Pêra
# Processing Record 270 | Voyvozh
# Processing Record 271 | Upernavik
# Processing Record 272 | Oxapampa
# Processing Record 273 | Koumac
# Processing Record 274 | Markova
# Processing Record 275 | Havre-St-Pierre
# Processing Record 276 | Woodstock
# Processing Record 277 | Mount Gambier
# Processing Record 278 | Narsaq
# Processing Record 279 | Avera
# Processing Record 280 | Quatre Cocos
# Processing Record 281 | Boa Vista
# Processing Record 282 | Tabou
# Processing Record 283 | La Macarena
# Processing Record 284 | Portoferraio
# City not found...
# Processing Record 285 | Gannan
# Processing Record 286 | Obo
# Processing Record 287 | Pandan
# Processing Record 288 | Dingcheng
# Processing Record 289 | Trelew
# Processing Record 290 | George
# Processing Record 291 | Svecha
# Processing Record 292 | Oxford
# Processing Record 293 | Krasnoarmiys'k
# Processing Record 294 | Kirakira
# Processing Record 295 | Sumbe
# Processing Record 296 | Cherskiy
# Processing Record 297 | Saint Anthony
# Processing Record 298 | Takoradze
# Processing Record 299 | Kisaran
# Processing Record 300 | Port Macquarie
# Processing Record 301 | Nantucket
# Processing Record 302 | Jizan
# Processing Record 303 | Jumla
# Processing Record 304 | Laguna
# Processing Record 305 | Rocky Mountain House
# Processing Record 306 | Zhangjiakou
# Processing Record 307 | Ostrovnoy
# Processing Record 308 | Tatarsk
# Processing Record 309 | Pilar
# City not found...
# Processing Record 310 | Vila Velha
# Processing Record 311 | Tanete
# Processing Record 312 | Mahébourg
# Processing Record 313 | Evensk
# City not found...
# Processing Record 314 | Palmer
# Processing Record 315 | Río Cuarto
# Processing Record 316 | East London
# Processing Record 317 | Iquitos
# Processing Record 318 | Portage
# Processing Record 319 | Haines Junction
# Processing Record 320 | Sampit
# Processing Record 321 | Ubari
# Processing Record 322 | Puerto Santander
# Processing Record 323 | Kaeo
# Processing Record 324 | Kiryat Gat
# Processing Record 325 | Clyde
# Processing Record 326 | Sochi
# Processing Record 327 | Guider
# Processing Record 328 | Machalí
# Processing Record 329 | Nome
# City not found...
# Processing Record 330 | Okhotsk
# Processing Record 331 | Maykor
# City not found...
# Processing Record 332 | Xinyu
# Processing Record 333 | Bāruipur
# Processing Record 334 | Leningradskiy
# Processing Record 335 | Cidreira
# Processing Record 336 | Aden
# Processing Record 337 | Camacha
# Processing Record 338 | Sonoita
# Processing Record 339 | Bonavista
# Processing Record 340 | Hirara
# Processing Record 341 | Pontes e Lacerda
# City not found...
# Processing Record 342 | Karratha
# Processing Record 343 | Ipixuna
# Processing Record 344 | Severo-Kuril'sk
# Processing Record 345 | Qandala
# Processing Record 346 | Ligayan
# Processing Record 347 | Faratsiho
# Processing Record 348 | Mastic Beach
# Processing Record 349 | Cabedelo
# Processing Record 350 | Krasnogorskoye
# Processing Record 351 | Kalmunai
# Processing Record 352 | Tromsø
# Processing Record 353 | Kuzhener
# Processing Record 354 | Port Saint Lucie
# Processing Record 355 | Phalodi
# Processing Record 356 | Broken Hill
# Processing Record 357 | Zyryanka
# Processing Record 358 | Coahuayana Viejo
# Processing Record 359 | Qaqortoq
# Processing Record 360 | Laas
# Processing Record 361 | Bontang
# Processing Record 362 | Sungai Penuh
# Processing Record 363 | Ambilobe
# Processing Record 364 | Krasnosel'kup
# Processing Record 365 | Kaitangata
# Processing Record 366 | Bridgetown
# Processing Record 367 | Mitsamiouli
# Processing Record 368 | Jaffna
# Processing Record 369 | Kandrian
# Processing Record 370 | Santa Rosalía
# Processing Record 371 | Kaoma
# City not found...
# Processing Record 372 | Balkanabat
# Processing Record 373 | São Félix do Xingu
# Processing Record 374 | São José da Coroa Grande
# Processing Record 375 | Shenzhen
# Processing Record 376 | Westport
# Processing Record 377 | Marabu
# Processing Record 378 | Kavieng
# Processing Record 379 | Camrose
# Processing Record 380 | Karīmganj
# Processing Record 381 | Maple Creek
# Processing Record 382 | Taoudenni
# Processing Record 383 | Nemuro
# Processing Record 384 | Gizo Government Station
# Processing Record 385 | Codrington
# Processing Record 386 | Osterburg
# Processing Record 387 | Bulgan
# Processing Record 388 | Kilindoni
# Processing Record 389 | São Gabriel da Cachoeira
# Processing Record 390 | Payo
# City not found...
# Processing Record 391 | Umluj
# Processing Record 392 | Mahajanga
# Processing Record 393 | Samarai
# Processing Record 394 | São João da Barra
# Processing Record 395 | Brae
# Processing Record 396 | Bandarbeyla
# Processing Record 397 | Talnakh
# Processing Record 398 | Bosaso
# City not found...
# Processing Record 399 | Nhulunbuy
# Processing Record 400 | Mumbwa
# Processing Record 401 | Belaya Gora
# Processing Record 402 | Callaway
# Processing Record 403 | Magistral'nyy
# Processing Record 404 | La Asuncion
# Processing Record 405 | Severo-Yeniseyskiy
# City not found...
# Processing Record 406 | Merauke
# Processing Record 407 | Uruçuí
# Processing Record 408 | Luohe
# Processing Record 409 | Mitú
# City not found...
# Processing Record 410 | San Jerónimo
# Processing Record 411 | Cochabamba
# Processing Record 412 | Pangoa
# Processing Record 413 | Nyzhni Sirohozy
# Processing Record 414 | Ürümqi
# Processing Record 415 | Beringovskiy
# Processing Record 416 | Tianpeng
# Processing Record 417 | Kasongo-Lunda
# Processing Record 418 | Zwedru
# Processing Record 419 | Rawson
# Processing Record 420 | Guerrero Negro
# Processing Record 421 | Culubasa
# Processing Record 422 | Hambantota
# Processing Record 423 | Ust-Maya
# Processing Record 424 | Tiznit Province
# Processing Record 425 | Bermeo
# Processing Record 426 | Panabá
# Processing Record 427 | Pacific Grove
# Processing Record 428 | Port Hedland
# Processing Record 429 | Guánica
# Processing Record 430 | Jalu
# Processing Record 431 | Sokolo
# Processing Record 432 | Hatta
# Processing Record 433 | Hammerfest
# Processing Record 434 | Beloha
# Processing Record 435 | La Rioja
# Processing Record 436 | Beşikdüzü
# Processing Record 437 | Mayo
# Processing Record 438 | Kishorganj
# City not found...
# City not found...
# Processing Record 439 | Guanagazapa
# Processing Record 440 | Petrozavodsk
# Processing Record 441 | Puerto Nariño
# Processing Record 442 | Belmonte
# Processing Record 443 | Ayr
# Processing Record 444 | Port Moresby
# Processing Record 445 | Manggar
# Processing Record 446 | Poronaysk
# Processing Record 447 | Balyqshy
# Processing Record 448 | Lawton
# Processing Record 449 | Vodnyy
# Processing Record 450 | Fort Dodge
# Processing Record 451 | Inhambane
# Processing Record 452 | Sarangani
# Processing Record 453 | Mount Isa
# Processing Record 454 | Baykit
# Processing Record 455 | Khovd
# Processing Record 456 | Iraq
# Processing Record 457 | Kropotkin
# Processing Record 458 | Ghanzi
# Processing Record 459 | Sitrah
# Processing Record 460 | Oksbøl
# Processing Record 461 | Terney
# Processing Record 462 | Senador José Porfírio
# Processing Record 463 | Marsaxlokk
# Processing Record 464 | Dwārka
# Processing Record 465 | Jinchang
# Processing Record 466 | Birao
# Processing Record 467 | Beisfjord
# Processing Record 468 | Arman'
# Processing Record 469 | Maromitsa
# Processing Record 470 | Fort Saint James
# Processing Record 471 | Alyangula
# Processing Record 472 | Dayong
# Processing Record 473 | Eden
# Processing Record 474 | Xiaoshi
# Processing Record 475 | Yar-Sale
# Processing Record 476 | Elbistan
# City not found...
# City not found...
# Processing Record 477 | Kigoma
# Processing Record 478 | Shitanjing
# Processing Record 479 | Graaff-Reinet
# Processing Record 480 | Eenhana
# City not found...
# Processing Record 481 | Oistins
# Processing Record 482 | Malinovoye Ozero
# City not found...
# Processing Record 483 | Qeshm
# Processing Record 484 | Antalaha
# Processing Record 485 | Santa Cruz de Barahona
# Processing Record 486 | Bozüyük
# Processing Record 487 | Makakilo City
# Processing Record 488 | Mlalo
# Processing Record 489 | Guaymas
# Processing Record 490 | Ulladulla
# Processing Record 491 | Lata
# Processing Record 492 | College
# Processing Record 493 | Tongchuanshi
# Processing Record 494 | Huilong
# Processing Record 495 | Mogadishu
# Processing Record 496 | Ha Tinh
# Processing Record 497 | Khor
# Processing Record 498 | Douentza
# Processing Record 499 | Port Blair
# Processing Record 500 | Porbandar
# Processing Record 501 | Guisijan
# Processing Record 502 | Balvi
# Processing Record 503 | Egvekinot
# Processing Record 504 | Nioaque
# Processing Record 505 | North Bend
# Processing Record 506 | Wattegama
# Processing Record 507 | Buala
# Processing Record 508 | Ixtapa
# Processing Record 509 | Balkhash
# Processing Record 510 | Palu
# Processing Record 511 | St. George's
# Processing Record 512 | Plettenberg Bay
# Processing Record 513 | Richards Bay
# Processing Record 514 | Lukovetskiy
# Processing Record 515 | Tutóia
# Processing Record 516 | Kahramanmaraş Province
# Processing Record 517 | Bartoszyce
# Processing Record 518 | Bulnes
# Processing Record 519 | Broome
# Processing Record 520 | Yaan
# Processing Record 521 | Labuan
# Processing Record 522 | Fomboni
# Processing Record 523 | Mayya
# Processing Record 524 | Marau
# Processing Record 525 | Arrondissement de Saint-Jean-de-Maurienne
# Processing Record 526 | Springbok
# Processing Record 527 | Strezhevoy
# Processing Record 528 | Hernani
# City not found...
# Processing Record 529 | Briançon
# Processing Record 530 | Flinders
# Processing Record 531 | Morehead
# Processing Record 532 | Nouadhibou
# Processing Record 533 | Cape Coast
# City not found...
# Processing Record 534 | Auki
# Processing Record 535 | Aksu
# Processing Record 536 | Arrondissement de Brive-la-Gaillarde
# Processing Record 537 | Fuxin
# Processing Record 538 | Peleduy
# Processing Record 539 | Usinsk
# City not found...
# Processing Record 540 | Tarauacá
# Processing Record 541 | Tefé
# Processing Record 542 | Kurchum
# Processing Record 543 | Vila
# Processing Record 544 | Port Lincoln
# Processing Record 545 | Zabaykal'sk
# Processing Record 546 | Krasnoshchekovo
# Processing Record 547 | Upata
# Processing Record 548 | Aquitania
# Processing Record 549 | Odesa
# Processing Record 550 | Tilichiki
# Processing Record 551 | Show Low
# Processing Record 552 | Grants
# Processing Record 553 | Angoche

# %%
weather_dict = {
    "City": city_name,
    "Lat": lat, 
    "Lng": lng, 
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness, 
    "Wind Speed": wind_speed,
    "Country": country,
    "Date":date
    
}


weather_df = pd.DataFrame(weather_dict)

# %%
weather_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
weather_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     80.56        80          63
# 1     Jamestown  42.0970  -79.2353     67.30        50           1
# 2     Busselton -33.6500  115.3333     54.09        74         100
# 3   Yellowknife  62.4560 -114.3525     45.41        76          40
# 4       Ushuaia -54.8000  -68.3000     58.66        47          40
#
#    Wind Speed Country        Date
# 0        9.98      EC  1634668091
# 1        3.00      US  1634668128
# 2       23.47      AU  1634667415
# 3        8.05      CA  1634667382
# 4       21.85      AR  1634668066

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  553.000000  553.000000  553.000000  553.000000  553.000000  553.000000
# mean    19.457531   18.241870   61.990253   70.016275   54.265823    7.793183
# std     33.308418   89.564813   21.233739   20.496856   39.485411    5.791039
# min    -54.800000 -179.166700  -19.410000    8.000000    0.000000    0.000000
# 25%     -8.161400  -64.711400   47.530000   57.000000   10.000000    3.440000
# 50%     22.349700   23.682100   68.450000   74.000000   58.000000    6.640000
# 75%     46.848400   94.666700   78.120000   86.000000   97.000000   10.400000
# max     78.218600  179.316700   98.330000  100.000000  100.000000   37.760000
#
#                Date
# count  5.530000e+02
# mean   1.634668e+09
# std    2.209757e+02
# min    1.634667e+09
# 25%    1.634668e+09
# 50%    1.634668e+09
# 75%    1.634668e+09
# max    1.634668e+09

# %%
weather_df.to_csv("raw_data/weather_cities_data.csv", index=False)

# %% [markdown]
# # Inspect the data and remove the cities where the humidity > 100%.

# %%
weather_sorting_df = weather_df.sort_values("Humidity", ascending=False)
weather_sorting_df.head(20)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 295       Cherskiy  68.7500  161.3000    -12.39       100         100
# 421     Hambantota   6.1241   81.1185     77.34       100           0
# 323     Kiryat Gat  31.6100   34.7642     72.28       100          42
# 124          Bāsār  27.9833   94.6667     68.61       100         100
# 356       Zyryanka  65.7500  150.8500     -3.78       100          65
# 443   Port Moresby  -9.4431  147.1797     72.82       100          20
# 184    Tuktoyaktuk  69.4541 -133.0374     15.80       100          40
# 168      Vestmanna  62.1564   -7.1664     49.12       100          90
# 400    Belaya Gora  68.5333  146.4167    -10.21        99          76
# 106     Micomeseng   2.1462   10.6164     69.39        99         100
# 389           Payo  -3.7508  103.6372     73.71        99          98
# 379      Karīmganj  24.8667   92.3500     73.69        98         100
# 256  Srednekolymsk  67.4500  153.6833     -6.66        98          45
# 474       Yar-Sale  66.8333   70.8333     32.70        98         100
# 319         Sampit  -2.5333  112.9500     73.71        98         100
# 98        Klaksvík  62.2266   -6.5890     50.92        98         100
# 302          Jumla  29.2747   82.1838     57.18        98         100
# 396        Talnakh  69.4865   88.3972     30.06        98          97
# 402  Magistral'nyy  56.1725  107.4458     31.77        98         100
# 207          Dukat  62.5500  155.5500     -2.33        98         100
#
#      Wind Speed Country        Date
# 295        3.91      RU  1634668176
# 421        2.30      LK  1634668255
# 323        4.94      IL  1634668139
# 124        1.45      IN  1634668178
# 356        4.16      RU  1634668239
# 443        5.75      PG  1634668262
# 184        5.75      CA  1634668029
# 168        6.91      FO  1634668187
# 400        4.56      RU  1634668248
# 106        3.78      GQ  1634668172
# 389        1.88      ID  1634667668
# 379        3.09      IN  1634668244
# 256        6.04      RU  1634668163
# 474       10.18      RU  1634668036
# 319        1.88      ID  1634668121
# 98         6.06      FO  1634668170
# 302        0.74      NP  1634668224
# 396        5.82      RU  1634668156
# 402        3.06      RU  1634668248
# 207        4.79      RU  1634668112

# %%
weather_cleansing_df = weather_df.loc[weather_df["Humidity"] <= 100]
weather_cleansing_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     80.56        80          63
# 1     Jamestown  42.0970  -79.2353     67.30        50           1
# 2     Busselton -33.6500  115.3333     54.09        74         100
# 3   Yellowknife  62.4560 -114.3525     45.41        76          40
# 4       Ushuaia -54.8000  -68.3000     58.66        47          40
#
#    Wind Speed Country        Date
# 0        9.98      EC  1634668091
# 1        3.00      US  1634668128
# 2       23.47      AU  1634667415
# 3        8.05      CA  1634667382
# 4       21.85      AR  1634668066

# %%
weather_sorting1_df = weather_cleansing_df.sort_values("Humidity", ascending=False)
weather_sorting1_df.head(20)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 295       Cherskiy  68.7500  161.3000    -12.39       100         100
# 421     Hambantota   6.1241   81.1185     77.34       100           0
# 323     Kiryat Gat  31.6100   34.7642     72.28       100          42
# 124          Bāsār  27.9833   94.6667     68.61       100         100
# 356       Zyryanka  65.7500  150.8500     -3.78       100          65
# 443   Port Moresby  -9.4431  147.1797     72.82       100          20
# 184    Tuktoyaktuk  69.4541 -133.0374     15.80       100          40
# 168      Vestmanna  62.1564   -7.1664     49.12       100          90
# 400    Belaya Gora  68.5333  146.4167    -10.21        99          76
# 106     Micomeseng   2.1462   10.6164     69.39        99         100
# 389           Payo  -3.7508  103.6372     73.71        99          98
# 379      Karīmganj  24.8667   92.3500     73.69        98         100
# 256  Srednekolymsk  67.4500  153.6833     -6.66        98          45
# 474       Yar-Sale  66.8333   70.8333     32.70        98         100
# 319         Sampit  -2.5333  112.9500     73.71        98         100
# 98        Klaksvík  62.2266   -6.5890     50.92        98         100
# 302          Jumla  29.2747   82.1838     57.18        98         100
# 396        Talnakh  69.4865   88.3972     30.06        98          97
# 402  Magistral'nyy  56.1725  107.4458     31.77        98         100
# 207          Dukat  62.5500  155.5500     -2.33        98         100
#
#      Wind Speed Country        Date
# 295        3.91      RU  1634668176
# 421        2.30      LK  1634668255
# 323        4.94      IL  1634668139
# 124        1.45      IN  1634668178
# 356        4.16      RU  1634668239
# 443        5.75      PG  1634668262
# 184        5.75      CA  1634668029
# 168        6.91      FO  1634668187
# 400        4.56      RU  1634668248
# 106        3.78      GQ  1634668172
# 389        1.88      ID  1634667668
# 379        3.09      IN  1634668244
# 256        6.04      RU  1634668163
# 474       10.18      RU  1634668036
# 319        1.88      ID  1634668121
# 98         6.06      FO  1634668170
# 302        0.74      NP  1634668224
# 396        5.82      RU  1634668156
# 402        3.06      RU  1634668248
# 207        4.79      RU  1634668112

# %%
weather_cleansing_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
#there are no cities that have humidity > 100%...

# %% [markdown]
# # Plotting the Data

# %%
weather_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     80.56        80          63
# 1     Jamestown  42.0970  -79.2353     67.30        50           1
# 2     Busselton -33.6500  115.3333     54.09        74         100
# 3   Yellowknife  62.4560 -114.3525     45.41        76          40
# 4       Ushuaia -54.8000  -68.3000     58.66        47          40
#
#    Wind Speed Country        Date
# 0        9.98      EC  1634668091
# 1        3.00      US  1634668128
# 2       23.47      AU  1634667415
# 3        8.05      CA  1634667382
# 4       21.85      AR  1634668066

# %%
#Latitude vs. Temperature 

plt.scatter(weather_df["Lat"], weather_df["Max Temp"], color = "blue")

plt.title("Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("Pictures/Latitude vs. Max Temperature.png")
plt.show()

# %%
#Latitude vs. Humidity

plt.scatter(weather_df["Lat"], weather_df["Humidity"], color = "blue")

plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("Pictures/Latitude vs. Humidity.png")
plt.show()

# %%
#Latitude vs. Cloudiness

plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], color = "blue")

plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("Pictures/Latitude vs. Cloudiness.png")
plt.show()

# %%
#Latitude vs. Wind Speed

plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], color = "blue")

plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")
plt.grid(True)
plt.savefig("Pictures/Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression

weather_regression1_df = weather_df.loc[weather_df["Lat"] >= 0]
weather_regression1_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1        Jamestown  42.0970  -79.2353     67.30        50           1
# 3      Yellowknife  62.4560 -114.3525     45.41        76          40
# 6  Siddharthanagar  27.5000   83.4500     73.67        97         100
# 7            Muros  42.7762   -9.0603     70.23        85          20
# 8       Srīvardhan  18.0333   73.0167     77.58        79          41
#
#    Wind Speed Country        Date
# 1        3.00      US  1634668128
# 3        8.05      CA  1634667382
# 6        5.10      NP  1634668152
# 7       11.90      ES  1634668086
# 8        5.39      IN  1634668152

# %%
x_values = weather_regression1_df["Lat"]
y_values = weather_regression1_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.savefig("Pictures/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("We can notice a negative correlation between the two variables")
# Out:
# The r-squared is: 0.7090839473282676
# We can notice a negative correlation between the two variables

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

weather_regression2_df = weather_df.loc[weather_df["Lat"] <0]
weather_regression2_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     80.56        80          63
# 2     Busselton -33.6500  115.3333     54.09        74         100
# 4       Ushuaia -54.8000  -68.3000     58.66        47          40
# 5       Hualmay -11.0964  -77.6139     69.30        71          75
# 9      Hokitika -42.7167  170.9667     45.48        88           9
#
#    Wind Speed Country        Date
# 0        9.98      EC  1634668091
# 2       23.47      AU  1634667415
# 4       21.85      AR  1634668066
# 5        8.77      PE  1634668008
# 9        4.43      NZ  1634668125

# %%
x_values = weather_regression2_df["Lat"]
y_values = weather_regression2_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.savefig("Pictures/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("We can notice a positve correlation between the two variables")
# Out:
# The r-squared is: 0.3984439332684061
# We can notice a positve correlation between the two variables

# %%
####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x_values = weather_regression1_df["Lat"]
y_values = weather_regression1_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("Pictures/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("There is no correlation between the two variables...")
# Out:
# The r-squared is: 0.01839328320196225
# There is no correlation between the two variables...

# %%
##Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x3_values = weather_regression2_df["Lat"]
y3_values = weather_regression2_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x3_values, y3_values)
regress_values = x3_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x3_values,y3_values)
plt.plot(x3_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.savefig("Pictures/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

plt.show()
print(f"The r-squared is: {rvalue**2}")
print("There is no correlation between the two variables...")
# Out:
# The r-squared is: 0.08453569623771878
# There is no correlation between the two variables...

# %%
##Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

x_values = weather_regression1_df["Lat"]
y_values = weather_regression1_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("Pictures/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("There is no correlation between the two variables...")
# Out:
# The r-squared is: 0.001790718616593933
# There is no correlation between the two variables...

# %%
###Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

x3_values = weather_regression2_df["Lat"]
y3_values = weather_regression2_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x3_values, y3_values)
regress_values = x3_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x3_values,y3_values)
plt.plot(x3_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.savefig("Pictures/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

plt.show()
print(f"The r-squared is: {rvalue**2}")
print("There is no correlation between the two variables...")
# Out:
# The r-squared is: 0.1962292523044625
# There is no correlation between the two variables...

# %%
#  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

x_values = weather_regression1_df["Lat"]
y_values = weather_regression1_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("Pictures/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("There is weak positive correlation between the two variables...")
# Out:
# The r-squared is: 0.05864242505612973
# There is weak positive correlation between the two variables...

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

x_values = weather_regression2_df["Lat"]
y_values = weather_regression2_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.savefig("Pictures/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
print("There is negative correlation between the two variables...")
# Out:
# The r-squared is: 0.10411852981370973
# There is negative correlation between the two variables...
